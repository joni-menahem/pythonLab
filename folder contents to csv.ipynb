# %% [markdown]
# create csv file with the following columns:
#
# Filename, Description, Keywords, Categories, Mature content, Editorial

# %%
import os

# folder path
dir_path = r'C:\Users\yonat\Desktop\ShutterStock'

# list to store files
res = []
# Iterate directory
for file in os.listdir(dir_path):
    # check only text files
    if file.endswith('.jpg'):
        res.append(file)
print(res)
# Out:
# ['By Joni Menahem-1.jpg', 'By Joni Menahem-10.jpg', 'By Joni Menahem-100.jpg', 'By Joni Menahem-101.jpg', 'By Joni Menahem-102.jpg', 'By Joni Menahem-103.jpg', 'By Joni Menahem-104.jpg', 'By Joni Menahem-105.jpg', 'By Joni Menahem-106.jpg', 'By Joni Menahem-107.jpg', 'By Joni Menahem-108.jpg', 'By Joni Menahem-109.jpg', 'By Joni Menahem-11.jpg', 'By Joni Menahem-110.jpg', 'By Joni Menahem-111.jpg', 'By Joni Menahem-112.jpg', 'By Joni Menahem-113.jpg', 'By Joni Menahem-114.jpg', 'By Joni Menahem-115.jpg', 'By Joni Menahem-116.jpg', 'By Joni Menahem-117.jpg', 'By Joni Menahem-118.jpg', 'By Joni Menahem-119.jpg', 'By Joni Menahem-12.jpg', 'By Joni Menahem-120.jpg', 'By Joni Menahem-121.jpg', 'By Joni Menahem-122.jpg', 'By Joni Menahem-123.jpg', 'By Joni Menahem-124.jpg', 'By Joni Menahem-125.jpg', 'By Joni Menahem-13.jpg', 'By Joni Menahem-14.jpg', 'By Joni Menahem-15.jpg', 'By Joni Menahem-16.jpg', 'By Joni Menahem-17.jpg', 'By Joni Menahem-18.jpg', 'By Joni Menahem-19.jpg', 'By Joni M
# ...

# %%
import pandas as pd

columns = ['Filename', 'Description', 'Keywords', 'Categories', 'Mature content', 'Editorial']

df = pd.DataFrame(columns=columns)

df['Filename'] = res

df['Mature content'] = 'No'

df['Editorial'] = 'No'

df['Categories'] = 'Parks/Outdoor'

# %%
df.to_csv('ShutterStock.csv', index=False)
df
# Out:
#                     Filename Description Keywords     Categories  \
# 0      By Joni Menahem-1.jpg         NaN      NaN  Parks/Outdoor
# 1     By Joni Menahem-10.jpg         NaN      NaN  Parks/Outdoor
# 2    By Joni Menahem-100.jpg         NaN      NaN  Parks/Outdoor
# 3    By Joni Menahem-101.jpg         NaN      NaN  Parks/Outdoor
# 4    By Joni Menahem-102.jpg         NaN      NaN  Parks/Outdoor
# ..                       ...         ...      ...            ...
# 120   By Joni Menahem-95.jpg         NaN      NaN  Parks/Outdoor
# 121   By Joni Menahem-96.jpg         NaN      NaN  Parks/Outdoor
# 122   By Joni Menahem-97.jpg         NaN      NaN  Parks/Outdoor
# 123   By Joni Menahem-98.jpg         NaN      NaN  Parks/Outdoor
# 124   By Joni Menahem-99.jpg         NaN      NaN  Parks/Outdoor
#
#     Mature content Editorial
# 0               No        No
# 1               No        No
# 2               No        No
# 3               No        No
# 4               No        No
# ...
